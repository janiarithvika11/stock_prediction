# %%
import yfinance as yf

# Example: get 1 month of daily data for Apple
data = yf.download(tickers="AAPL", period="1mo", interval="1h")  # 1-hour interval
data.dropna(inplace=True)
print(data.head())
# Out:
# C:\Users\mural\AppData\Local\Temp\ipykernel_74260\2943661162.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers="AAPL", period="1mo", interval="1h")  # 1-hour interval
# [*********************100%***********************]  1 of 1 completed
# Price                           Close        High         Low        Open  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Datetime
# 2025-09-04 13:30:00+00:00  237.690002  239.893204  237.039993  238.449997
# 2025-09-04 14:30:00+00:00  237.399994  238.100006  237.074997  237.679993
# 2025-09-04 15:30:00+00:00  237.160004  237.674606  236.740005  237.389999
# 2025-09-04 16:30:00+00:00  238.039993  238.089996  236.970001  237.149994
# 2025-09-04 17:30:00+00:00  238.059998  238.389999  237.509995  238.040100
#
# Price                        Volume
# Ticker                         AAPL
# Datetime
# 2025-09-04 13:30:00+00:00  12016131
# 2025-09-04 14:30:00+00:00   5223309
# 2025-09-04 15:30:00+00:00   3678939
# 2025-09-04 16:30:00+00:00   3071522
# 2025-09-04 17:30:00+00:00   5093419

# %%
import pandas as pd

df = data.copy()
# Price movement features
df['Price_Change'] = df['Close'] - df['Open']
df['High_Low'] = df['High'] - df['Low']
df['MA5'] = df['Close'].rolling(5).mean()
df['MA10'] = df['Close'].rolling(10).mean()
df['Volume_Change'] = df['Volume'].pct_change()

# Target variable: will price go UP in next period?
df['Target'] = (df['Close'].shift(-1) > df['Close']).astype(int)

# Drop NaNs generated by rolling / shift
df.dropna(inplace=True)

print(df.head())
# Out:
# Price                           Close        High         Low        Open  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Datetime
# 2025-09-05 15:30:00+00:00  238.770004  240.315002  238.520004  239.820007
# 2025-09-05 16:30:00+00:00  239.625000  239.725006  238.490097  238.779999
# 2025-09-05 17:30:00+00:00  239.119995  239.649994  238.729996  239.648499
# 2025-09-05 18:30:00+00:00  239.925003  240.130005  239.100006  239.119995
# 2025-09-05 19:30:00+00:00  239.669998  240.014999  239.059998  239.929993
#
# Price                       Volume Price_Change  High_Low         MA5  \
# Ticker                        AAPL
# Datetime
# 2025-09-05 15:30:00+00:00  4219870    -1.050003  1.794998  239.254901
# 2025-09-05 16:30:00+00:00  3993359     0.845001  1.234909  239.439001
# 2025-09-05 17:30:00+00:00  2784543    -0.528503  0.919998  239.320999
# 2025-09-05 18:30:00+00:00  5197093     0.805008  1.029999  239.448999
# 2025-09-05 19:30:00+00:00  4868520    -0.259995  0.955002  239.422000
#
# Price                            MA10 Volume_Change Target
# Ticker
# Datetime
# 2025-09-05 15:30:00+00:00  238.462450     -0.354583      1
# 2025-09-05 16:30:00+00:00  238.655949     -0.053677      0
# 2025-09-05 17:30:00+00:00  238.827950     -0.302707      1
# 2025-09-05 18:30:00+00:00  239.104449      0.866408      0
# 2025-09-05 19:30:00+00:00  239.267450     -0.063222      0

# %%
print(df.columns.tolist())
# Out:
# ['Close_AAPL', 'High_AAPL', 'Low_AAPL', 'Open_AAPL', 'Volume_AAPL', 'Price_Change_', 'High_Low_', 'MA5_', 'MA10_', 'Volume_Change_', 'Target_']

# %%
print(df.head())
# Out:
#                            Close_AAPL   High_AAPL    Low_AAPL   Open_AAPL  \
# Datetime
# 2025-09-05 15:30:00+00:00  238.770004  240.315002  238.520004  239.820007
# 2025-09-05 16:30:00+00:00  239.625000  239.725006  238.490097  238.779999
# 2025-09-05 17:30:00+00:00  239.119995  239.649994  238.729996  239.648499
# 2025-09-05 18:30:00+00:00  239.925003  240.130005  239.100006  239.119995
# 2025-09-05 19:30:00+00:00  239.669998  240.014999  239.059998  239.929993
#
#                            Volume_AAPL  Price_Change_  High_Low_        MA5_  \
# Datetime
# 2025-09-05 15:30:00+00:00      4219870      -1.050003   1.794998  239.254901
# 2025-09-05 16:30:00+00:00      3993359       0.845001   1.234909  239.439001
# 2025-09-05 17:30:00+00:00      2784543      -0.528503   0.919998  239.320999
# 2025-09-05 18:30:00+00:00      5197093       0.805008   1.029999  239.448999
# 2025-09-05 19:30:00+00:00      4868520      -0.259995   0.955002  239.422000
#
#                                 MA10_  Volume_Change_  Target_
# Datetime
# 2025-09-05 15:30:00+00:00  238.462450       -0.354583        1
# 2025-09-05 16:30:00+00:00  238.655949       -0.053677        0
# 2025-09-05 17:30:00+00:00  238.827950       -0.302707        1
# 2025-09-05 18:30:00+00:00  239.104449        0.866408        0
# 2025-09-05 19:30:00+00:00  239.267450       -0.063222        0

# %%
# Flatten multi-level columns if necessary
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ['_'.join(col).strip() for col in df.columns]

# Now clean column names for LightGBM
df.columns = [
    col.replace(" ", "_")
       .replace("(", "")
       .replace(")", "")
       .replace("%", "pct")
       .replace("/", "_")
       .replace("-", "_")
    for col in df.columns
]

# %%
# Flatten multi-index if exists
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ['_'.join(col).strip() for col in df.columns]

# Clean names
df.columns = [col.replace(" ", "_").replace("(", "").replace(")", "")
                  .replace("%", "pct").replace("/", "_").replace("-", "_")
              for col in df.columns]

print(df.columns.tolist())  # Verify that all feature names exist
# Out:
# ['Close_AAPL', 'High_AAPL', 'Low_AAPL', 'Open_AAPL', 'Volume_AAPL', 'Price_Change_', 'High_Low_', 'MA5_', 'MA10_', 'Volume_Change_', 'Target_']

# %%
features = print(df.head())
features = ['Price_Change_', 'High_Low_', 'MA5_', 'MA10_', 'Volume_Change_']
X = df[features]
y = df['Target_']
# Out:
#                            Close_AAPL   High_AAPL    Low_AAPL   Open_AAPL  \
# Datetime
# 2025-09-05 15:30:00+00:00  238.770004  240.315002  238.520004  239.820007
# 2025-09-05 16:30:00+00:00  239.625000  239.725006  238.490097  238.779999
# 2025-09-05 17:30:00+00:00  239.119995  239.649994  238.729996  239.648499
# 2025-09-05 18:30:00+00:00  239.925003  240.130005  239.100006  239.119995
# 2025-09-05 19:30:00+00:00  239.669998  240.014999  239.059998  239.929993
#
#                            Volume_AAPL  Price_Change_  High_Low_        MA5_  \
# Datetime
# 2025-09-05 15:30:00+00:00      4219870      -1.050003   1.794998  239.254901
# 2025-09-05 16:30:00+00:00      3993359       0.845001   1.234909  239.439001
# 2025-09-05 17:30:00+00:00      2784543      -0.528503   0.919998  239.320999
# 2025-09-05 18:30:00+00:00      5197093       0.805008   1.029999  239.448999
# 2025-09-05 19:30:00+00:00      4868520      -0.259995   0.955002  239.422000
#
#                                 MA10_  Volume_Change_  Target_
# Datetime
# 2025-09-05 15:30:00+00:00  238.462450       -0.354583        1
# 2025-09-05 16:30:00+00:00  238.655949       -0.053677        0
# 2025-09-05 17:30:00+00:00  238.827950       -0.302707        1
# 2025-09-05 18:30:00+00:00  239.104449        0.866408        0
# 2025-09-05 19:30:00+00:00  239.267450       -0.063222        0

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score

model = LGBMClassifier()
model.fit(X_train, y_train)

# Evaluate
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Model Accuracy:", acc)
# Out:
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# Cell In[39], line 5
#       2 from sklearn.metrics import accuracy_score
#       4 model = LGBMClassifier()
# ----> 5 model.fit(X_train, y_train)
#       7 # Evaluate
#       8 y_pred = model.predict(X_test)
#
# File c:\Users\mural\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightgbm\sklearn.py:1560, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1557         else:
#    1558             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1560 super().fit(
#    1561     X,
#    1562     _y,
#    1563     sample_weight=sample_weight,
#    1564     init_score=init_score,
#    1565     eval_set=valid_sets,
#    1566     eval_names=eval_names,
#    1567     eval_sample_weight=eval_sample_weight,
#    1568     eval_class_weight=eval_class_weight,
#    1569     eval_init_score=eval_init_score,
#    1570     eval_metric=eval_metric,
#    1571     feature_name=feature_name,
#    1572     categorical_feature=categorical_feature,
#    1573     callbacks=callbacks,
#    1574     init_model=init_model,
#    1575 )
#    1576 return self
#
# File c:\Users\mural\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightgbm\sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File c:\Users\mural\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightgbm\engine.py:297, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     295 # construct booster
#     296 try:
# --> 297     booster = Booster(params=params, train_set=train_set)
#     298     if is_valid_contain_train:
#     299         booster.set_train_data_name(train_data_name)
#
# File c:\Users\mural\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightgbm\basic.py:3656, in Booster.__init__(self, params, train_set, model_file, model_str)
#    3649     self.set_network(
#    3650         machines=machines,
#    3651         local_listen_port=params["local_listen_port"],
#    3652         listen_time_out=params.get("time_out", 120),
#    3653         num_machines=params["num_machines"],
#    3654     )
#    3655 # construct booster object
# -> 3656 train_set.construct()
#    3657 # copy the parameters from train_set
#    3658 params.update(train_set.get_params())
#
# File c:\Users\mural\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightgbm\basic.py:2590, in Dataset.construct(self)
#    2585             self._set_init_score_by_predictor(
#    2586                 predictor=self._predictor, data=self.data, used_indices=used_indices
#    2587             )
#    2588 else:
#    2589     # create train
# -> 2590     self._lazy_init(
#    2591         data=self.data,
#    2592         label=self.label,
#    2593         reference=None,
#    2594         weight=self.weight,
#    2595         group=self.group,
#    2596         init_score=self.init_score,
#    2597         predictor=self._predictor,
#    2598         feature_name=self.feature_name,
#    2599         categorical_feature=self.categorical_feature,
#    2600         params=self.params,
#    2601         position=self.position,
#    2602     )
#    2603 if self.free_raw_data:
#    2604     self.data = None
#
# File c:\Users\mural\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightgbm\basic.py:2227, in Dataset._lazy_init(self, data, label, reference, weight, group, init_score, predictor, feature_name, categorical_feature, params, position)
#    2225     raise TypeError(f"Wrong predictor type {type(predictor).__name__}")
#    2226 # set feature names
# -> 2227 return self.set_feature_name(feature_name)
#
# File c:\Users\mural\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightgbm\basic.py:3046, in Dataset.set_feature_name(self, feature_name)
#    3042         raise ValueError(
#    3043             f"Length of feature_name({len(feature_name)}) and num_feature({self.num_feature()}) don't match"
#    3044         )
#    3045     c_feature_name = [_c_str(name) for name in feature_name]
# -> 3046     _safe_call(
#    3047         _LIB.LGBM_DatasetSetFeatureNames(
#    3048             self._handle,
#    3049             _c_array(ctypes.c_char_p, c_feature_name),
#    3050             ctypes.c_int(len(feature_name)),
#    3051         )
#    3052     )
#    3053 return self
#
# File c:\Users\mural\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightgbm\basic.py:313, in _safe_call(ret)
#     305 """Check the return value from C API call.
#     306
#     307 Parameters
#    (...)    310     The return value from C API calls.
#     311 """
#     312 if ret != 0:
# --> 313     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
#
# LightGBMError: Do not support special JSON characters in feature name.

# %%
print(df.columns.tolist())
# Out:
# ['Close_AAPL', 'High_AAPL', 'Low_AAPL', 'Open_AAPL', 'Volume_AAPL', 'Price_Change_', 'High_Low_', 'MA5_', 'MA10_', 'Volume_Change_', 'Target_']

# %%
features = ['Price_Change_', 'High_Low_', 'MA5_', 'MA10_', 'Volume_Change_']
X = df[features]
y = df['Target_']

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Train LightGBM
model = LGBMClassifier()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# [LightGBM] [Info] Number of positive: 57, number of negative: 59
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 199
# [LightGBM] [Info] Number of data points in the train set: 116, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.491379 -> initscore=-0.034486
# [LightGBM] [Info] Start training from score -0.034486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Accuracy: 0.41379310344827586

# %%
# Predict for the latest available data point
latest_features = X.tail(1)
prediction = model.predict(latest_features)[0]
direction = "UP ⬆️" if prediction == 1 else "DOWN ⬇️"
print("Next movement prediction:", direction)
# Out:
# Next movement prediction: DOWN ⬇️
